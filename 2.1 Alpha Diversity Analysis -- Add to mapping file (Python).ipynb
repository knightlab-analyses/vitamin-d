# %% [markdown]
# #### This notebook is to add alpha diversities to existing mapping file

# %%
import pandas as pd
import numpy as np

# %%
mf = pd.read_csv('../data/mapping_MrOS_add.txt', sep='\t', dtype=str, index_col='#SampleID')

# %%
mf.head()
# Out:
#           BarcodeSequence  LinkerPrimerSequence  \
# #SampleID
# BI0023       TCTGGTGACATT  GGACTACHVGGGTWTCTAAT
# BI0056       CAAGCATGCCTA  GGACTACHVGGGTWTCTAAT
# BI0131       CTATTTGCGACA  GGACTACHVGGGTWTCTAAT
# BI0153       ATCGGCGTTACA  GGACTACHVGGGTWTCTAAT
# BI0215       CCTCTCGTGATC  GGACTACHVGGGTWTCTAAT
#
#                                Experiment_Design_Description  \
# #SampleID
# BI0023     16S stool samples sequenced for MrOS Vitamin D...
# BI0056     16S stool samples sequenced for MrOS Vitamin D...
# BI0131     16S stool samples sequenced for MrOS Vitamin D...
# BI0153     16S stool samples sequenced for MrOS Vitamin D...
# BI0215     16S stool samples sequenced for MrOS Vitamin D...
#
#           Library_Construction_Protocol Linker  Platform Center_Name  \
# #SampleID
# BI0023                      16S rRNA v4     GT  Illumina          BI
# BI0056                      16S rRNA v4     GT  Illumina          BI
# BI0131                      16S rRNA v4     GT  Illumina          BI
# BI0153                      16S rRNA v4     GT  Illumina          BI
# BI0215                      16S rRNA v4     GT  Illumina          BI
#
#           Center_Project Instrument_Model          Title     ...      \
# #SampleID                                                    ...
# BI0023              MrOS   Illumina MiSeq  MrOS_VitaminD     ...
# BI0056              MrOS   Illumina MiSeq  MrOS_VitaminD     ...
# BI0131              MrOS   Illumina MiSeq  MrOS_VitaminD     ...
# BI0153              MrOS   Illumina MiSeq  MrOS_VitaminD     ...
# BI0215              MrOS   Illumina MiSeq  MrOS_VitaminD     ...
#
#                 Description       ratio_activation     ratio_catabolism  \
# #SampleID
# BI0023     Orwoll.BI0023.BI  0.0015232558139534882   0.0686046511627907
# BI0056     Orwoll.BI0056.BI   0.001579081632653061  0.09974489795918368
# BI0131     Orwoll.BI0131.BI   0.002255411255411255  0.06450216450216449
# BI0153     Orwoll.BI0153.BI  0.0015787545787545787  0.07838827838827839
# BI0215     Orwoll.BI0215.BI  0.0015212121212121212   0.1096969696969697
#
#                      QLCOMP M1STATIN Antihistamine Laxative  MIDATA  \
# #SampleID
# BI0023     1:GOOD/EXCELLENT    0: No          0:No     0:No  1: Yes
# BI0056     1:GOOD/EXCELLENT    0: No          0:No     0:No  1: Yes
# BI0131     1:GOOD/EXCELLENT   1: Yes          0:No     0:No  1: Yes
# BI0153     1:GOOD/EXCELLENT   1: Yes          0:No     0:No  1: Yes
# BI0215     1:GOOD/EXCELLENT    0: No          0:No     0:No  1: Yes
#
#                 Rstarch_total Rstarches_c
# #SampleID
# BI0023               3.066569         0.0
# BI0056               3.038136         0.0
# BI0131               2.840599         0.0
# BI0153               4.106798         0.0
# BI0215     0.9711139999999999         0.0
#
# [5 rows x 73 columns]

# %%
mf.shape
# Out:
# (599, 73)

# %% [markdown]
# ## add rarefied PD alpha diversity

# %%
alpha_PD = pd.read_csv('../Qiime_updated/alpha_PD/alpha-diversity.tsv', sep='\t', index_col=0)

# %%
alpha_PD.head()
# Out:
#          faith_pd
# MN1696  13.829871
# PI4923  20.079199
# PA3754  28.237103
# PI4717  18.456517
# PA3960  13.869326

# %%
alpha_PD.rename(columns={'faith_pd': 'alpha_pd'}, inplace=True)

# %%
df = pd.merge(mf, alpha_PD, left_index=True, right_index=True)

# %%
df.shape
# Out:
# (599, 74)

# %%
df.head()
# Out:
#        BarcodeSequence  LinkerPrimerSequence  \
# BI0023    TCTGGTGACATT  GGACTACHVGGGTWTCTAAT
# BI0056    CAAGCATGCCTA  GGACTACHVGGGTWTCTAAT
# BI0131    CTATTTGCGACA  GGACTACHVGGGTWTCTAAT
# BI0153    ATCGGCGTTACA  GGACTACHVGGGTWTCTAAT
# BI0215    CCTCTCGTGATC  GGACTACHVGGGTWTCTAAT
#
#                             Experiment_Design_Description  \
# BI0023  16S stool samples sequenced for MrOS Vitamin D...
# BI0056  16S stool samples sequenced for MrOS Vitamin D...
# BI0131  16S stool samples sequenced for MrOS Vitamin D...
# BI0153  16S stool samples sequenced for MrOS Vitamin D...
# BI0215  16S stool samples sequenced for MrOS Vitamin D...
#
#        Library_Construction_Protocol Linker  Platform Center_Name  \
# BI0023                   16S rRNA v4     GT  Illumina          BI
# BI0056                   16S rRNA v4     GT  Illumina          BI
# BI0131                   16S rRNA v4     GT  Illumina          BI
# BI0153                   16S rRNA v4     GT  Illumina          BI
# BI0215                   16S rRNA v4     GT  Illumina          BI
#
#        Center_Project Instrument_Model          Title    ...      \
# BI0023           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
# BI0056           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
# BI0131           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
# BI0153           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
# BI0215           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
#
#              ratio_activation     ratio_catabolism            QLCOMP M1STATIN  \
# BI0023  0.0015232558139534882   0.0686046511627907  1:GOOD/EXCELLENT    0: No
# BI0056   0.001579081632653061  0.09974489795918368  1:GOOD/EXCELLENT    0: No
# BI0131   0.002255411255411255  0.06450216450216449  1:GOOD/EXCELLENT   1: Yes
# BI0153  0.0015787545787545787  0.07838827838827839  1:GOOD/EXCELLENT   1: Yes
# BI0215  0.0015212121212121212   0.1096969696969697  1:GOOD/EXCELLENT    0: No
#
#        Antihistamine Laxative  MIDATA       Rstarch_total Rstarches_c  \
# BI0023          0:No     0:No  1: Yes            3.066569         0.0
# BI0056          0:No     0:No  1: Yes            3.038136         0.0
# BI0131          0:No     0:No  1: Yes            2.840599         0.0
# BI0153          0:No     0:No  1: Yes            4.106798         0.0
# BI0215          0:No     0:No  1: Yes  0.9711139999999999         0.0
#
#          alpha_pd
# BI0023  27.771167
# BI0056  17.932659
# BI0131  21.453663
# BI0153  18.469675
# BI0215  20.049827
#
# [5 rows x 74 columns]

# %% [markdown]
# ## add Observed OTUs

# %%
alpha_OTU = pd.read_csv('../Qiime_updated/alpha_ObsOTU/alpha-diversity.tsv', sep='\t', index_col=0)

# %%
df = pd.merge(df, alpha_OTU, left_index=True, right_index=True)

# %%
df.shape
# Out:
# (599, 75)

# %%
df.head()
# Out:
#        BarcodeSequence  LinkerPrimerSequence  \
# BI0023    TCTGGTGACATT  GGACTACHVGGGTWTCTAAT
# BI0056    CAAGCATGCCTA  GGACTACHVGGGTWTCTAAT
# BI0131    CTATTTGCGACA  GGACTACHVGGGTWTCTAAT
# BI0153    ATCGGCGTTACA  GGACTACHVGGGTWTCTAAT
# BI0215    CCTCTCGTGATC  GGACTACHVGGGTWTCTAAT
#
#                             Experiment_Design_Description  \
# BI0023  16S stool samples sequenced for MrOS Vitamin D...
# BI0056  16S stool samples sequenced for MrOS Vitamin D...
# BI0131  16S stool samples sequenced for MrOS Vitamin D...
# BI0153  16S stool samples sequenced for MrOS Vitamin D...
# BI0215  16S stool samples sequenced for MrOS Vitamin D...
#
#        Library_Construction_Protocol Linker  Platform Center_Name  \
# BI0023                   16S rRNA v4     GT  Illumina          BI
# BI0056                   16S rRNA v4     GT  Illumina          BI
# BI0131                   16S rRNA v4     GT  Illumina          BI
# BI0153                   16S rRNA v4     GT  Illumina          BI
# BI0215                   16S rRNA v4     GT  Illumina          BI
#
#        Center_Project Instrument_Model          Title      ...       \
# BI0023           MrOS   Illumina MiSeq  MrOS_VitaminD      ...
# BI0056           MrOS   Illumina MiSeq  MrOS_VitaminD      ...
# BI0131           MrOS   Illumina MiSeq  MrOS_VitaminD      ...
# BI0153           MrOS   Illumina MiSeq  MrOS_VitaminD      ...
# BI0215           MrOS   Illumina MiSeq  MrOS_VitaminD      ...
#
#            ratio_catabolism            QLCOMP M1STATIN Antihistamine Laxative  \
# BI0023   0.0686046511627907  1:GOOD/EXCELLENT    0: No          0:No     0:No
# BI0056  0.09974489795918368  1:GOOD/EXCELLENT    0: No          0:No     0:No
# BI0131  0.06450216450216449  1:GOOD/EXCELLENT   1: Yes          0:No     0:No
# BI0153  0.07838827838827839  1:GOOD/EXCELLENT   1: Yes          0:No     0:No
# BI0215   0.1096969696969697  1:GOOD/EXCELLENT    0: No          0:No     0:No
#
#         MIDATA       Rstarch_total Rstarches_c   alpha_pd observed_otus
# BI0023  1: Yes            3.066569         0.0  27.771167           302
# BI0056  1: Yes            3.038136         0.0  17.932659           173
# BI0131  1: Yes            2.840599         0.0  21.453663           223
# BI0153  1: Yes            4.106798         0.0  18.469675           223
# BI0215  1: Yes  0.9711139999999999         0.0  20.049827           222
#
# [5 rows x 75 columns]

# %% [markdown]
# ## add Shannon diversity

# %%
alpha_shannon = pd.read_csv('../Qiime_updated/alpha_Shannon/alpha-diversity.tsv', sep='\t', index_col=0)

# %%
alpha_shannon.head()
# Out:
#          shannon
# MN1696  3.964419
# PI4923  5.281535
# PA3754  5.557438
# PI4717  5.556278
# PA3960  4.775712

# %%
df = pd.merge(df, alpha_shannon, left_index=True, right_index=True)

# %%
df.shape
# Out:
# (599, 76)

# %%
df.head()
# Out:
#        BarcodeSequence  LinkerPrimerSequence  \
# BI0023    TCTGGTGACATT  GGACTACHVGGGTWTCTAAT
# BI0056    CAAGCATGCCTA  GGACTACHVGGGTWTCTAAT
# BI0131    CTATTTGCGACA  GGACTACHVGGGTWTCTAAT
# BI0153    ATCGGCGTTACA  GGACTACHVGGGTWTCTAAT
# BI0215    CCTCTCGTGATC  GGACTACHVGGGTWTCTAAT
#
#                             Experiment_Design_Description  \
# BI0023  16S stool samples sequenced for MrOS Vitamin D...
# BI0056  16S stool samples sequenced for MrOS Vitamin D...
# BI0131  16S stool samples sequenced for MrOS Vitamin D...
# BI0153  16S stool samples sequenced for MrOS Vitamin D...
# BI0215  16S stool samples sequenced for MrOS Vitamin D...
#
#        Library_Construction_Protocol Linker  Platform Center_Name  \
# BI0023                   16S rRNA v4     GT  Illumina          BI
# BI0056                   16S rRNA v4     GT  Illumina          BI
# BI0131                   16S rRNA v4     GT  Illumina          BI
# BI0153                   16S rRNA v4     GT  Illumina          BI
# BI0215                   16S rRNA v4     GT  Illumina          BI
#
#        Center_Project Instrument_Model          Title    ...     \
# BI0023           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
# BI0056           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
# BI0131           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
# BI0153           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
# BI0215           MrOS   Illumina MiSeq  MrOS_VitaminD    ...
#
#                   QLCOMP M1STATIN Antihistamine Laxative  MIDATA  \
# BI0023  1:GOOD/EXCELLENT    0: No          0:No     0:No  1: Yes
# BI0056  1:GOOD/EXCELLENT    0: No          0:No     0:No  1: Yes
# BI0131  1:GOOD/EXCELLENT   1: Yes          0:No     0:No  1: Yes
# BI0153  1:GOOD/EXCELLENT   1: Yes          0:No     0:No  1: Yes
# BI0215  1:GOOD/EXCELLENT    0: No          0:No     0:No  1: Yes
#
#              Rstarch_total Rstarches_c   alpha_pd observed_otus   shannon
# BI0023            3.066569         0.0  27.771167           302  5.727116
# BI0056            3.038136         0.0  17.932659           173  3.888281
# BI0131            2.840599         0.0  21.453663           223  4.050730
# BI0153            4.106798         0.0  18.469675           223  4.894253
# BI0215  0.9711139999999999         0.0  20.049827           222  5.295055
#
# [5 rows x 76 columns]

# %% [markdown]
# ## Pielou (Evenness)

# %%
alpha_evenness = pd.read_csv('../Qiime_updated/alpha_Evenness/alpha-diversity.tsv', sep='\t', index_col=0)

# %%
df = pd.merge(df, alpha_evenness, left_index=True, right_index=True)

# %%
df.head()
# Out:
#        BarcodeSequence  LinkerPrimerSequence  \
# BI0023    TCTGGTGACATT  GGACTACHVGGGTWTCTAAT
# BI0056    CAAGCATGCCTA  GGACTACHVGGGTWTCTAAT
# BI0131    CTATTTGCGACA  GGACTACHVGGGTWTCTAAT
# BI0153    ATCGGCGTTACA  GGACTACHVGGGTWTCTAAT
# BI0215    CCTCTCGTGATC  GGACTACHVGGGTWTCTAAT
#
#                             Experiment_Design_Description  \
# BI0023  16S stool samples sequenced for MrOS Vitamin D...
# BI0056  16S stool samples sequenced for MrOS Vitamin D...
# BI0131  16S stool samples sequenced for MrOS Vitamin D...
# BI0153  16S stool samples sequenced for MrOS Vitamin D...
# BI0215  16S stool samples sequenced for MrOS Vitamin D...
#
#        Library_Construction_Protocol Linker  Platform Center_Name  \
# BI0023                   16S rRNA v4     GT  Illumina          BI
# BI0056                   16S rRNA v4     GT  Illumina          BI
# BI0131                   16S rRNA v4     GT  Illumina          BI
# BI0153                   16S rRNA v4     GT  Illumina          BI
# BI0215                   16S rRNA v4     GT  Illumina          BI
#
#        Center_Project Instrument_Model          Title    ...    M1STATIN  \
# BI0023           MrOS   Illumina MiSeq  MrOS_VitaminD    ...       0: No
# BI0056           MrOS   Illumina MiSeq  MrOS_VitaminD    ...       0: No
# BI0131           MrOS   Illumina MiSeq  MrOS_VitaminD    ...      1: Yes
# BI0153           MrOS   Illumina MiSeq  MrOS_VitaminD    ...      1: Yes
# BI0215           MrOS   Illumina MiSeq  MrOS_VitaminD    ...       0: No
#
#        Antihistamine Laxative  MIDATA       Rstarch_total Rstarches_c  \
# BI0023          0:No     0:No  1: Yes            3.066569         0.0
# BI0056          0:No     0:No  1: Yes            3.038136         0.0
# BI0131          0:No     0:No  1: Yes            2.840599         0.0
# BI0153          0:No     0:No  1: Yes            4.106798         0.0
# BI0215          0:No     0:No  1: Yes  0.9711139999999999         0.0
#
#          alpha_pd observed_otus   shannon  pielou_e
# BI0023  27.771167           302  5.727116  0.695173
# BI0056  17.932659           173  3.888281  0.522996
# BI0131  21.453663           223  4.050730  0.519264
# BI0153  18.469675           223  4.894253  0.627396
# BI0215  20.049827           222  5.295055  0.679340
#
# [5 rows x 77 columns]

# %%
df.shape
# Out:
# (599, 77)

# %% [markdown]
# ## export

# %%
df.to_csv('../data/mros_mapping_alpha.txt', sep='\t', index_label='#SampleID')
