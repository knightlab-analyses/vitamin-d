# %% [markdown]
# #### This notebook is to perform Non-Redundant Analysis on alpha diversities

# %% [markdown]
# ##### reference: Falony G, Joossens M, Vieira-Silva S, et al. Population-level analysis of gut microbiome variation. Science 2016;352:560-4

# %%
library(vegan)
# Out:
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-5

# %%
mf = read.csv('../data/mros_mapping_alpha.txt', stringsAsFactors=FALSE, sep='\t')
colnames(mf)[1] = 'SampleName'
dim(mf)
# Out:
# [1] 598  76

# %%
names(mf)
# Out:
#  [1] "SampleName"                    "BarcodeSequence"
#  [3] "LinkerPrimerSequence"          "Experiment_Design_Description"
#  [5] "Library_Construction_Protocol" "Linker"
#  [7] "Platform"                      "Center_Name"
#  [9] "Center_Project"                "Instrument_Model"
# [11] "Title"                         "Anonymized_Name"
# [13] "Scientific_Name"               "Taxon_ID"
# [15] "Sample_Type"                   "Geo_Loc_Name"
# [17] "Elevation"                     "Env_Biome"
# [19] "Env_Feature"                   "Env_Material"
# [21] "Env_Package"                   "Latitude"
# [23] "Longitude"                     "Collection_Timestamp"
# [25] "DNA_Extracted"                 "Physical_Specimen_Location"
# [27] "Physical_Specimen_Remaining"   "Age"
# [29] "Age_Units"                     "Host_Subject_ID"
# [31] "Host_Taxid"                    "Host_Scientific_Name"
# [33] "Host_Common_Name"              "Life_Stage"
# [35] "Sex"                           "Height"
# [37] "Height_Units"                  "Weight"
# [39] "Weight_Units"                  "BMI"
# [41] "Body_Habitat"                  "Body_Site"
# [43] "Body_Product"                  "GIERACE"
# [45] "SITE"                          "TUDRAMT"
# [47] "PASCORE"                       "TURSMOKE"
# [49] "DTVITD"                        "M1ADEPR"
# [51] "M1VITMND"                      "M1ANTIB"
# [53] "M1PROBI"                       "OHV1D3"
# [55] "OHV24D3"                       "OHVD3"
# [57] "OHVD2"                         "OHV1D2"
# [59] "OHV1D2CT"                      "OHVD2CT"
# [61] "OHVDTOT"                       "OHV1DTOT"
# [63] "OHSEAS"                        "VDstatus"
# [65] "Description"                   "ratio_activation"
# [67] "ratio_catabolism"              "QLCOMP"
# [69] "M1STATIN"                      "Antihistamine"
# [71] "Laxative"                      "MIDATA"
# [73] "Rstarch_total"                 "Rstarches_c"
# [75] "M1PPUMP"                       "alpha_pd"

# %%
head(mf)
# Out:
#   SampleName BarcodeSequence LinkerPrimerSequence
# 1 BI0023     TCTGGTGACATT    GGACTACHVGGGTWTCTAAT
# 2 BI0056     CAAGCATGCCTA    GGACTACHVGGGTWTCTAAT
# 3 BI0131     CTATTTGCGACA    GGACTACHVGGGTWTCTAAT
# 4 BI0153     ATCGGCGTTACA    GGACTACHVGGGTWTCTAAT
# 5 BI0215     CCTCTCGTGATC    GGACTACHVGGGTWTCTAAT
# 6 BI0353     TGCCATCTGAAT    GGACTACHVGGGTWTCTAAT
#   Experiment_Design_Description
# 1 16S stool samples sequenced for MrOS Vitamin D study
# 2 16S stool samples sequenced for MrOS Vitamin D study
# 3 16S stool samples sequenced for MrOS Vitamin D study
# 4 16S stool samples sequenced for MrOS Vitamin D study
# 5 16S stool samples sequenced for MrOS Vitamin D study
# 6 16S stool samples sequenced for MrOS Vitamin D study
#   Library_Construction_Protocol Linker Platform Center_Name Center_Project
# 1 16S rRNA v4                   GT     Illumina BI          MrOS
# 2 16S rRNA v4                   GT     Illumina BI          MrOS
# 3 16S rRNA v4                   GT     Illumina BI          MrOS
# 4 16S rRNA v4                   GT     Illumina BI          MrOS
# 5 16S rRNA v4                   GT     Illumina BI          MrOS
# 6 16S rRNA v4                   GT     Illumina BI          MrOS
#   Instrument_Model ... ratio_catabolism QLCOMP           M1STATIN Antihistamine
# 1 Illumina MiSeq   ... 0.06860465       1:GOOD/EXCELLENT 0: No    0:No
# 2 Illumina MiSeq   ... 0.09974490       1:GOOD/EXCELLENT 0: No    0:No
# 3 Illumina MiSeq   ... 0.06450216       1:GOOD/EXCELLENT 1: Yes   0:No
# 4 Illumina MiSeq   ... 0.07838828       1:GOOD/EXCELLENT 1: Yes   0:No
# 5 Illumina MiSeq   ... 0.10969697       1:GOOD/EXCELLENT 0: No    0:No
# 6 Illumina MiSeq   ... 0.09179487       1:GOOD/EXCELLENT 1: Yes   0:No
#   Laxative MIDATA Rstarch_total Rstarches_c M1PPUMP alpha_pd
# 1 0:No     1: Yes 3.066569      0           0: No   30.02140
# 2 0:No     1: Yes 3.038136      0           1: Yes  18.41498
# 3 0:No     1: Yes 2.840599      0           0: No   25.75695
# 4 0:No     1: Yes 4.106798      0           0: No   20.16791
# 5 0:No     1: Yes 0.971114      0           0: No   20.71433
# 6 0:No     1: Yes 4.813568      0           0: No   14.17015

# %%
sapply(mf, class)
# Out:
#                    SampleName               BarcodeSequence
#                   "character"                   "character"
#          LinkerPrimerSequence Experiment_Design_Description
#                   "character"                   "character"
# Library_Construction_Protocol                        Linker
#                   "character"                   "character"
#                      Platform                   Center_Name
#                   "character"                   "character"
#                Center_Project              Instrument_Model
#                   "character"                   "character"
#                         Title               Anonymized_Name
#                   "character"                   "character"
#               Scientific_Name                      Taxon_ID
#                   "character"                   "character"
#                   Sample_Type                  Geo_Loc_Name
#                   "character"                   "character"
#                     Elevation                     Env_Biome
#                   "character"                   "character"
#                   Env_Feature                  Env_Material
#                   "character"                   "character"
#                   Env_Package                      Latitude
#                   "character"                     "numeric"
#                     Longitude          Collection_Timestamp
#                     "numeric"                   "character"
#                 DNA_Extracted    Physical_Specimen_Location
#                   "character"                   "character"
#   Physical_Specimen_Remaining                           Age
#                   "character"                     "integer"
#                     Age_Units               Host_Subject_ID
#                   "character"                   "character"
#                    Host_Taxid          Host_Scientific_Name
#                   "character"                   "character"
#              Host_Common_Name                    Life_Stage
#                   "character"                   "character"
#                           Sex                        Height
#                   "character"                     "numeric"
#                  Height_Units                        Weight
#                   "character"                     "numeric"
#                  Weight_Units                           BMI
#                   "character"                     "numeric"
#                  Body_Habitat                     Body_Site
#                   "character"                   "character"
#                  Body_Product                       GIERACE
#                   "character"                   "character"
#                          SITE                       TUDRAMT
#                   "character"                   "character"
#                       PASCORE                      TURSMOKE
#                     "numeric"                   "character"
#                        DTVITD                       M1ADEPR
#                     "numeric"                   "character"
#                      M1VITMND                       M1ANTIB
#                   "character"                   "character"
#                       M1PROBI                        OHV1D3
#                   "character"                     "numeric"
#                       OHV24D3                         OHVD3
#                     "numeric"                     "numeric"
#                         OHVD2                        OHV1D2
#                     "numeric"                     "numeric"
#                      OHV1D2CT                       OHVD2CT
#                   "character"                   "character"
#                       OHVDTOT                      OHV1DTOT
#                     "numeric"                     "numeric"
#                        OHSEAS                      VDstatus
#                   "character"                   "character"
#                   Description              ratio_activation
#                   "character"                     "numeric"
#              ratio_catabolism                        QLCOMP
#                     "numeric"                   "character"
#                      M1STATIN                 Antihistamine
#                   "character"                   "character"
#                      Laxative                        MIDATA
#                   "character"                   "character"
#                 Rstarch_total                   Rstarches_c
#                     "numeric"                     "numeric"
#                       M1PPUMP                      alpha_pd
#                   "character"                     "numeric"

# %%
# not include correlated variables
# convert categorial to factors
vars_cat = c('Sex','GIERACE', 'SITE', 'TUDRAMT', 'TURSMOKE', 'M1ADEPR', 'M1VITMND', 'M1ANTIB', 'M1PROBI', 
               'OHSEAS', 'QLCOMP', 'VDstatus', 'M1STATIN', 'Antihistamine', 'Laxative', 'M1PPUMP')
mf[vars_cat] = lapply(mf[vars_cat], factor)

# convert continuous to numeric
vars_cts = c('Latitude', 'Longitude', 'Age', 'BMI', 'PASCORE', 'DTVITD', 'Rstarch_total',
             'OHV1D3', 'OHV24D3', 'OHVD3', 'alpha_pd')

# %%
length(vars_cat)
length(vars_cts)
# Out:
# [1] 16
# [1] 11

# %%
dat = mf[c(vars_cat, vars_cts)]
dim(dat)
head(dat)
# Out:
# [1] 598  27
#   Sex  GIERACE SITE       TUDRAMT                         TURSMOKE
# 1 male 1:WHITE Birmingham 1: Less than one drink per week M:Not Applicable
# 2 male 1:WHITE Birmingham 0:None drinker                  1:PAST
# 3 male 1:WHITE Birmingham 0:None drinker                  1:PAST
# 4 male 1:WHITE Birmingham 4: 6-13 drinks per week         1:PAST
# 5 male 1:WHITE Birmingham 3: 3-5 drinks per week          1:PAST
# 6 male 1:WHITE Birmingham 0:None drinker                  1:PAST
#   M1ADEPR M1VITMND M1ANTIB M1PROBI OHSEAS   ... Longitude Age BMI
# 1 0: No   0: No    0: No   0: No   3:SUMMER ... -86.80249 83  28.89012
# 2 0: No   1: Yes   1: Yes  0: No   2:SPRING ... -86.80249 81  28.53980
# 3 0: No   1: Yes   0: No   0: No   2:SPRING ... -86.80249 83  25.01424
# 4 0: No   1: Yes   0: No   0: No   2:SPRING ... -86.80249 79  30.87637
# 5 0: No   0: No    0: No   0: No   4:FALL   ... -86.80249 81  33.58739
# 6 0: No   0: No    1: Yes  0: No   2:SPRING ... -86.80249 80  26.41523
#   PASCORE   DTVITD Rstarch_total OHV1D3 OHV24D3 OHVD3 alpha_pd
# 1  91.00000 250.90 3.066569      0.0393 1.77    25.8  30.02140
# 2 199.17857  72.97 3.038136      0.0619 3.91    39.2  18.41498
# 3 161.71429 312.15 2.840599      0.0521 1.49    23.1  25.75695
# 4  88.21429 323.52 4.106798      0.0431 2.14    27.3  20.16791
# 5 256.82143  31.95 0.971114      0.0502 3.62    33.0  20.71433
# 6 179.57143 156.06 4.813568      0.0455 1.79    19.5  14.17015

# %%
summary(dat)
# Out:
#    Sex                    GIERACE             SITE
#  male:598   1:WHITE           :520   Birmingham : 75
#             2:AFRICAN AMERICAN: 24   Minneapolis: 91
#             3:ASIAN           : 33   Palo Alto  : 86
#             4:HISPANIC        : 12   Pittsburgh : 92
#             5:OTHER           :  9   Portland   :121
#                                      San Diego  :133
#
#                             TUDRAMT                TURSMOKE     M1ADEPR
#  .                              :  2   0:NO            :230   0: No :545
#  0:None drinker                 :229   1:PAST          :288   1: Yes: 53
#  1: Less than one drink per week: 78   2:CURRENT       :  9
#  2: 1-2drinks per week          : 66   M:Not Applicable: 71
#  3: 3-5 drinks per week         : 90
#  4: 6-13 drinks per week        :106
#  5: 14 or more drinks per week  : 27
#    M1VITMND     M1ANTIB      M1PROBI                       OHSEAS
#  0: No :154   0: No :557   0: No :572   1:WINTER              :  6
#  1: Yes:444   1: Yes: 41   1: Yes: 26   2:SPRING              :210
#                                         3:SUMMER              :220
#                                         4:FALL                :130
#                                         Missing:Not collected : 32
#
#
#               QLCOMP                      VDstatus     M1STATIN   Antihistamine
#  0:PR/VPOOR/FAIR : 66                         : 11   0: No :263   0:No :539
#  1:GOOD/EXCELLENT:532   deficiency            : 40   1: Yes:335   1:Yes: 59
#                         Missing:Not collected : 32
#                         sufficiency           :515
#
#
#
#   Laxative     M1PPUMP       Latitude       Longitude           Age
#  0:No :505   0: No :482   Min.   :32.72   Min.   :-122.7   Min.   :78.00
#  1:Yes: 93   1: Yes:116   1st Qu.:33.52   1st Qu.:-122.1   1st Qu.:81.00
#                           Median :40.44   Median :-117.2   Median :83.00
#                           Mean   :39.14   Mean   :-105.8   Mean   :84.24
#                           3rd Qu.:44.98   3rd Qu.: -86.8   3rd Qu.:87.00
#                           Max.   :45.52   Max.   : -80.0   Max.   :98.00
#
#       BMI           PASCORE           DTVITD        Rstarch_total
#  Min.   :17.60   Min.   :  0.00   Min.   :  0.429   Min.   : 0.100
#  1st Qu.:24.52   1st Qu.: 70.39   1st Qu.: 78.140   1st Qu.: 1.250
#  Median :26.73   Median :117.09   Median :128.230   Median : 2.358
#  Mean   :27.02   Mean   :122.60   Mean   :164.595   Mean   : 2.680
#  3rd Qu.:28.98   3rd Qu.:165.89   3rd Qu.:211.795   3rd Qu.: 3.601
#  Max.   :42.93   Max.   :359.14   Max.   :982.830   Max.   :12.386
#                                   NA's   :15        NA's   :15
#      OHV1D3           OHV24D3           OHVD3           alpha_pd
#  Min.   :0.01070   Min.   : 0.300   Min.   :  7.80   Min.   : 5.367
#  1st Qu.:0.04412   1st Qu.: 2.167   1st Qu.: 27.40   1st Qu.:17.413
#  Median :0.05550   Median : 3.185   Median : 33.60   Median :21.754
#  Mean   :0.05780   Mean   : 3.431   Mean   : 35.22   Mean   :22.470
#  3rd Qu.:0.06635   3rd Qu.: 4.237   3rd Qu.: 41.85   3rd Qu.:27.560
#  Max.   :0.15600   Max.   :14.070   Max.   :104.00   Max.   :45.017
#  NA's   :32        NA's   :32       NA's   :43

# %%
dat = dat[complete.cases(dat), ]
print(dim(dat))
alpha = dat$alpha_pd
dat = dat[, -which(names(dat) %in% 'alpha_pd')]
dim(dat)
# Out:
# [1] 544  27
# [1] 544  26

# %%
set.seed(3120)
mod0 <- rda(alpha ~ 1., dat)  # Model with intercept only
mod1 <- rda(alpha ~ ., dat)  # Model with all explanatory variables

# %%
step.res <- ordiR2step(mod0, mod1, perm.max = 1000)
# Out:
# Step: R2.adj= 0
# Call: alpha ~ 1
#
#                   R2.adjusted
# <All variables>  0.1354698752
# + OHV1D3         0.0500120037
# + SITE           0.0263409016
# + GIERACE        0.0234820196
# + M1ANTIB        0.0201196819
# + TUDRAMT        0.0188079337
# + Latitude       0.0159837702
# + M1ADEPR        0.0119743677
# + OHV24D3        0.0101469821
# + Rstarch_total  0.0091500619
# + BMI            0.0066765171
# + PASCORE        0.0045608444
# + Longitude      0.0041515130
# + Age            0.0038126671
# + OHSEAS         0.0037997809
# + M1STATIN       0.0006994564
# <none>           0.0000000000
# + Sex            0.0000000000
# + VDstatus      -0.0001648986
# + M1PROBI       -0.0003667234
# + Laxative      -0.0003769385
# + QLCOMP        -0.0008197335
# + OHVD3         -0.0014072837
# + Antihistamine -0.0015976317
# + M1PPUMP       -0.0017030367
# + M1VITMND      -0.0018291107
# + DTVITD        -0.0018429080
# + TURSMOKE      -0.0053224948
#
#          Df    AIC      F Pr(>F)
# + OHV1D3  1 2047.8 29.586  0.002 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.050012
# Call: alpha ~ OHV1D3
#
#                 R2.adjusted
# <All variables>  0.13546988
# + SITE           0.07306590
# + GIERACE        0.07153396
# + Latitude       0.06670629
# + M1ANTIB        0.06534616
# + Rstarch_total  0.06318009
# + TUDRAMT        0.06036220
# + M1ADEPR        0.05853680
# + Age            0.05714770
# + OHSEAS         0.05600666
# + OHVD3          0.05592531
# + Longitude      0.05263747
# + M1STATIN       0.05207032
# + BMI            0.05187720
# + M1PROBI        0.05177403
# + M1VITMND       0.05172570
# + Laxative       0.05021610
# + PASCORE        0.05015421
# <none>           0.05001200
# + Sex            0.05001200
# + OHV24D3        0.04906201
# + M1PPUMP        0.04894858
# + Antihistamine  0.04836119
# + VDstatus       0.04835683
# + DTVITD         0.04832332
# + QLCOMP         0.04827224
# + TURSMOKE       0.04522913
#
#        Df    AIC     F Pr(>F)
# + SITE  5 2039.3 3.696  0.004 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.0730659
# Call: alpha ~ OHV1D3 + SITE
#
#                 R2.adjusted
# <All variables>  0.13546988
# + GIERACE        0.09361662
# + M1ANTIB        0.08441259
# + M1ADEPR        0.08187529
# + Rstarch_total  0.08137184
# + TUDRAMT        0.08008812
# + Age            0.07966889
# + OHVD3          0.07736793
# + OHSEAS         0.07576787
# + M1STATIN       0.07539320
# + M1VITMND       0.07515465
# + PASCORE        0.07461755
# + M1PROBI        0.07448734
# + BMI            0.07446311
# + Laxative       0.07374935
# <none>           0.07306590
# + Sex            0.07306590
# + Latitude       0.07306590
# + Longitude      0.07306590
# + M1PPUMP        0.07211582
# + OHV24D3        0.07205838
# + DTVITD         0.07171333
# + Antihistamine  0.07160069
# + VDstatus       0.07136098
# + QLCOMP         0.07134516
# + TURSMOKE       0.06794946
#
#           Df    AIC      F Pr(>F)
# + GIERACE  4 2031.1 4.0439  0.002 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.09361662
# Call: alpha ~ OHV1D3 + SITE + GIERACE
#
#                 R2.adjusted
# <All variables>  0.13546988
# + M1ANTIB        0.10527296
# + M1ADEPR        0.10431095
# + OHVD3          0.10071662
# + Rstarch_total  0.09893819
# + OHSEAS         0.09861437
# + Age            0.09827281
# + BMI            0.09716391
# + PASCORE        0.09692545
# + M1PROBI        0.09569827
# + M1STATIN       0.09551619
# + Laxative       0.09537025
# + TUDRAMT        0.09525663
# + M1VITMND       0.09519986
# <none>           0.09361662
# + Sex            0.09361662
# + Latitude       0.09361662
# + Longitude      0.09361662
# + OHV24D3        0.09348831
# + M1PPUMP        0.09291319
# + DTVITD         0.09269946
# + Antihistamine  0.09224869
# + VDstatus       0.09191454
# + QLCOMP         0.09191299
# + TURSMOKE       0.08851811
#
#           Df  AIC      F Pr(>F)
# + M1ANTIB  1 2025 7.9438   0.01 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.105273
# Call: alpha ~ OHV1D3 + SITE + GIERACE + M1ANTIB
#
#                 R2.adjusted
# <All variables>   0.1354699
# + M1ADEPR         0.1162603
# + OHVD3           0.1128067
# + OHSEAS          0.1115132
# + Rstarch_total   0.1100681
# + Age             0.1094335
# + PASCORE         0.1084144
# + TUDRAMT         0.1082534
# + BMI             0.1077679
# + M1STATIN        0.1072243
# + Laxative        0.1069559
# + M1VITMND        0.1060733
# + M1PROBI         0.1059728
# + OHV24D3         0.1057285
# <none>            0.1052730
# + Sex             0.1052730
# + Latitude        0.1052730
# + Longitude       0.1052730
# + M1PPUMP         0.1045616
# + DTVITD          0.1042586
# + Antihistamine   0.1036867
# + QLCOMP          0.1036189
# + VDstatus        0.1036077
# + TURSMOKE        0.1002225
#
#           Df    AIC      F Pr(>F)
# + M1ADEPR  1 2019.3 7.6142  0.006 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.1162603
# Call: alpha ~ OHV1D3 + SITE + GIERACE + M1ANTIB + M1ADEPR
#
#                 R2.adjusted
# <All variables>   0.1354699
# + OHVD3           0.1218764
# + OHSEAS          0.1211001
# + Age             0.1204058
# + Rstarch_total   0.1197829
# + BMI             0.1194588
# + PASCORE         0.1190609
# + TUDRAMT         0.1179709
# + M1STATIN        0.1179327
# + Laxative        0.1177448
# + M1PROBI         0.1172165
# + M1VITMND        0.1169693
# <none>            0.1162603
# + Sex             0.1162603
# + Latitude        0.1162603
# + Longitude       0.1162603
# + OHV24D3         0.1160372
# + M1PPUMP         0.1151959
# + DTVITD          0.1151209
# + QLCOMP          0.1146439
# + VDstatus        0.1145964
# + Antihistamine   0.1145943
# + TURSMOKE        0.1113604
#
#         Df    AIC     F Pr(>F)
# + OHVD3  1 2016.8 4.396   0.05 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.1218764
# Call: alpha ~ OHV1D3 + SITE + GIERACE + M1ANTIB + M1ADEPR + OHVD3
#
#                 R2.adjusted
# <All variables>   0.1354699
# + OHSEAS          0.1266897
# + Age             0.1261782
# + BMI             0.1257577
# + M1STATIN        0.1252720
# + Rstarch_total   0.1251100
# + PASCORE         0.1246608
# + TUDRAMT         0.1240069
# + Laxative        0.1235301
# + M1PROBI         0.1227620
# <none>            0.1218764
# + Sex             0.1218764
# + Latitude        0.1218764
# + Longitude       0.1218764
# + OHV24D3         0.1214187
# + VDstatus        0.1211925
# + M1PPUMP         0.1210387
# + M1VITMND        0.1208258
# + DTVITD          0.1205481
# + QLCOMP          0.1202428
# + Antihistamine   0.1202165
# + TURSMOKE        0.1169549
#
#          Df    AIC      F Pr(>F)
# + OHSEAS  3 2016.7 1.9737  0.116

# %%
table = step.res$anova
table
# Out:
#                 R2.adj     Df AIC      F         Pr(>F)
# + OHV1D3        0.05001200  1 2047.745 29.586170 0.002
# + SITE          0.07306590  5 2039.339  3.696031 0.004
# + GIERACE       0.09361662  4 2031.075  4.043893 0.002
# + M1ANTIB       0.10527296  1 2025.012  7.943827 0.010
# + M1ADEPR       0.11626027  1 2019.267  7.614217 0.006
# + OHVD3         0.12187635  1 2016.774  4.396036 0.050
# <All variables> 0.13546988 NA       NA        NA    NA

# %%
table$ES.RDA = c(table$R2.adj[1], table$R2.adj[2]-table$R2.adj[1], 
                 table$R2.adj[3]-table$R2.adj[2], table$R2.adj[4]-table$R2.adj[3],
                 table$R2.adj[5]-table$R2.adj[4], table$R2.adj[6]-table$R2.adj[5],
                 table$R2.adj[7]-table$R2.adj[6])
table = table[-7, ]

# %%
step.res$call
# Out:
# rda(formula = alpha ~ OHV1D3 + SITE + GIERACE + M1ANTIB + M1ADEPR +
#     OHVD3, data = dat)

# %%
table
# Out:
#           R2.adj     Df AIC      F         Pr(>F) ES.RDA
# + OHV1D3  0.05001200 1  2047.745 29.586170 0.002  0.050012004
# + SITE    0.07306590 5  2039.339  3.696031 0.004  0.023053899
# + GIERACE 0.09361662 4  2031.075  4.043893 0.002  0.020550721
# + M1ANTIB 0.10527296 1  2025.012  7.943827 0.010  0.011656341
# + M1ADEPR 0.11626027 1  2019.267  7.614217 0.006  0.010987305
# + OHVD3   0.12187635 1  2016.774  4.396036 0.050  0.005616082

# %%
rownames(table) = c('1,25-(OH)2D', 'Site', 'Race', 'Oral Antibiotic Use', 'Antidepressant Use', '25(OH)D')

# %%
# export
write.table(table, file='../data/RDA_alpha_table.txt', sep='\t', col.names=NA)

# %%
library(ggplot2)
pdf('../figures/RDA_alpha.pdf')
covariates = rownames(table)
ggplot(table, aes(x=reorder(covariates, ES.RDA), y=ES.RDA, fill=covariates)) +
  labs(x = 'Non-redundant Covariants', y = 'Effect Size (PD Alpha Diversity)') +
  geom_bar(stat='identity') + 
  scale_fill_manual(values = c("#F8766D", "#DE8C00", "#7CAE00", "#00BA38", "#619CFF", "#C77CFF")) + 
  scale_x_discrete(labels = c('25(OH)D', 'Antidepressant Use', 'Oral Antibiotic Use', 'Race','Site', expression('1,25(OH)'[2]*'D'))) +
  theme(axis.text=element_text(size=14, face='bold'), 
       axis.title=element_text(size=17,face="bold"), 
       legend.position="none") + 
  coord_flip()
dev.off()
# Out:
# pdf
#   2
