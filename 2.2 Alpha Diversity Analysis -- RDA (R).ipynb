# %% [markdown]
# #### This notebook is to perform Non-Redundant Analysis on alpha diversities

# %% [markdown]
# ##### reference: Falony G, Joossens M, Vieira-Silva S, et al. Population-level analysis of gut microbiome variation. Science 2016;352:560-4

# %%
library(vegan)
# Out:
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-5

# %%
mf = read.csv('../data/mros_mapping_alpha.txt', stringsAsFactors=FALSE, sep='\t')
colnames(mf)[1] = 'SampleName'
dim(mf)
# Out:
# [1] 599  78

# %%
names(mf)
# Out:
#  [1] "SampleName"                    "BarcodeSequence"
#  [3] "LinkerPrimerSequence"          "Experiment_Design_Description"
#  [5] "Library_Construction_Protocol" "Linker"
#  [7] "Platform"                      "Center_Name"
#  [9] "Center_Project"                "Instrument_Model"
# [11] "Title"                         "Anonymized_Name"
# [13] "Scientific_Name"               "Taxon_ID"
# [15] "Sample_Type"                   "Geo_Loc_Name"
# [17] "Elevation"                     "Env_Biome"
# [19] "Env_Feature"                   "Env_Material"
# [21] "Env_Package"                   "Latitude"
# [23] "Longitude"                     "Collection_Timestamp"
# [25] "DNA_Extracted"                 "Physical_Specimen_Location"
# [27] "Physical_Specimen_Remaining"   "Age"
# [29] "Age_Units"                     "Host_Subject_ID"
# [31] "Host_Taxid"                    "Host_Scientific_Name"
# [33] "Host_Common_Name"              "Life_Stage"
# [35] "Sex"                           "Height"
# [37] "Height_Units"                  "Weight"
# [39] "Weight_Units"                  "BMI"
# [41] "Body_Habitat"                  "Body_Site"
# [43] "Body_Product"                  "GIERACE"
# [45] "SITE"                          "TUDRAMT"
# [47] "PASCORE"                       "TURSMOKE"
# [49] "DTVITD"                        "M1ADEPR"
# [51] "M1VITMND"                      "M1ANTIB"
# [53] "M1PROBI"                       "OHV1D3"
# [55] "OHV24D3"                       "OHVD3"
# [57] "OHVD2"                         "OHV1D2"
# [59] "OHV1D2CT"                      "OHVD2CT"
# [61] "OHVDTOT"                       "OHV1DTOT"
# [63] "OHSEAS"                        "VDstatus"
# [65] "Description"                   "ratio_activation"
# [67] "ratio_catabolism"              "QLCOMP"
# [69] "M1STATIN"                      "Antihistamine"
# [71] "Laxative"                      "MIDATA"
# [73] "Rstarch_total"                 "Rstarches_c"
# [75] "alpha_pd"                      "observed_otus"
# [77] "shannon"                       "pielou_e"

# %%
head(mf)
# Out:
#   SampleName BarcodeSequence LinkerPrimerSequence
# 1 BI0023     TCTGGTGACATT    GGACTACHVGGGTWTCTAAT
# 2 BI0056     CAAGCATGCCTA    GGACTACHVGGGTWTCTAAT
# 3 BI0131     CTATTTGCGACA    GGACTACHVGGGTWTCTAAT
# 4 BI0153     ATCGGCGTTACA    GGACTACHVGGGTWTCTAAT
# 5 BI0215     CCTCTCGTGATC    GGACTACHVGGGTWTCTAAT
# 6 BI0353     TGCCATCTGAAT    GGACTACHVGGGTWTCTAAT
#   Experiment_Design_Description
# 1 16S stool samples sequenced for MrOS Vitamin D study
# 2 16S stool samples sequenced for MrOS Vitamin D study
# 3 16S stool samples sequenced for MrOS Vitamin D study
# 4 16S stool samples sequenced for MrOS Vitamin D study
# 5 16S stool samples sequenced for MrOS Vitamin D study
# 6 16S stool samples sequenced for MrOS Vitamin D study
#   Library_Construction_Protocol Linker Platform Center_Name Center_Project
# 1 16S rRNA v4                   GT     Illumina BI          MrOS
# 2 16S rRNA v4                   GT     Illumina BI          MrOS
# 3 16S rRNA v4                   GT     Illumina BI          MrOS
# 4 16S rRNA v4                   GT     Illumina BI          MrOS
# 5 16S rRNA v4                   GT     Illumina BI          MrOS
# 6 16S rRNA v4                   GT     Illumina BI          MrOS
#   Instrument_Model ⋯ M1STATIN Antihistamine Laxative MIDATA Rstarch_total
# 1 Illumina MiSeq   ⋯ 0: No    0:No          0:No     1: Yes 3.066569
# 2 Illumina MiSeq   ⋯ 0: No    0:No          0:No     1: Yes 3.038136
# 3 Illumina MiSeq   ⋯ 1: Yes   0:No          0:No     1: Yes 2.840599
# 4 Illumina MiSeq   ⋯ 1: Yes   0:No          0:No     1: Yes 4.106798
# 5 Illumina MiSeq   ⋯ 0: No    0:No          0:No     1: Yes 0.971114
# 6 Illumina MiSeq   ⋯ 1: Yes   0:No          0:No     1: Yes 4.813568
#   Rstarches_c alpha_pd observed_otus shannon  pielou_e
# 1 0           27.77117 302           5.727116 0.6951729
# 2 0           17.93266 173           3.888281 0.5229960
# 3 0           21.45366 223           4.050730 0.5192645
# 4 0           18.46968 223           4.894253 0.6273959
# 5 0           20.04983 222           5.295055 0.6793396
# 6 0           13.75183 155           4.213016 0.5790192

# %%
sapply(mf, class)
# Out:
#                    SampleName               BarcodeSequence
#                   "character"                   "character"
#          LinkerPrimerSequence Experiment_Design_Description
#                   "character"                   "character"
# Library_Construction_Protocol                        Linker
#                   "character"                   "character"
#                      Platform                   Center_Name
#                   "character"                   "character"
#                Center_Project              Instrument_Model
#                   "character"                   "character"
#                         Title               Anonymized_Name
#                   "character"                   "character"
#               Scientific_Name                      Taxon_ID
#                   "character"                   "character"
#                   Sample_Type                  Geo_Loc_Name
#                   "character"                   "character"
#                     Elevation                     Env_Biome
#                   "character"                   "character"
#                   Env_Feature                  Env_Material
#                   "character"                   "character"
#                   Env_Package                      Latitude
#                   "character"                     "numeric"
#                     Longitude          Collection_Timestamp
#                     "numeric"                   "character"
#                 DNA_Extracted    Physical_Specimen_Location
#                   "character"                   "character"
#   Physical_Specimen_Remaining                           Age
#                   "character"                     "integer"
#                     Age_Units               Host_Subject_ID
#                   "character"                   "character"
#                    Host_Taxid          Host_Scientific_Name
#                   "character"                   "character"
#              Host_Common_Name                    Life_Stage
#                   "character"                   "character"
#                           Sex                        Height
#                   "character"                     "numeric"
#                  Height_Units                        Weight
#                   "character"                     "numeric"
#                  Weight_Units                           BMI
#                   "character"                     "numeric"
#                  Body_Habitat                     Body_Site
#                   "character"                   "character"
#                  Body_Product                       GIERACE
#                   "character"                   "character"
#                          SITE                       TUDRAMT
#                   "character"                   "character"
#                       PASCORE                      TURSMOKE
#                     "numeric"                   "character"
#                        DTVITD                       M1ADEPR
#                     "numeric"                   "character"
#                      M1VITMND                       M1ANTIB
#                   "character"                   "character"
#                       M1PROBI                        OHV1D3
#                   "character"                     "numeric"
#                       OHV24D3                         OHVD3
#                     "numeric"                     "numeric"
#                         OHVD2                        OHV1D2
#                     "numeric"                     "numeric"
#                      OHV1D2CT                       OHVD2CT
#                   "character"                   "character"
#                       OHVDTOT                      OHV1DTOT
#                     "numeric"                     "numeric"
#                        OHSEAS                      VDstatus
#                   "character"                   "character"
#                   Description              ratio_activation
#                   "character"                     "numeric"
#              ratio_catabolism                        QLCOMP
#                     "numeric"                   "character"
#                      M1STATIN                 Antihistamine
#                   "character"                   "character"
#                      Laxative                        MIDATA
#                   "character"                   "character"
#                 Rstarch_total                   Rstarches_c
#                     "numeric"                     "numeric"
#                      alpha_pd                 observed_otus
#                     "numeric"                     "integer"
#                       shannon                      pielou_e
#                     "numeric"                     "numeric"

# %%
# not include correlated variables
# convert categorial to factors
vars_cat = c('Sex','GIERACE', 'SITE', 'TUDRAMT', 'TURSMOKE', 'M1ADEPR', 'M1VITMND', 'M1ANTIB', 'M1PROBI', 
               'OHSEAS', 'QLCOMP', 'VDstatus', 'M1STATIN', 'Antihistamine', 'Laxative')
mf[vars_cat] = lapply(mf[vars_cat], factor)

# convert continuous to numeric
vars_cts = c('Latitude', 'Longitude', 'Age', 'BMI', 'PASCORE', 'DTVITD', 'Rstarch_total',
             'OHV1D3', 'OHV24D3', 'OHVD3', 'alpha_pd')

# %%
length(vars_cat)
length(vars_cts)
# Out:
# [1] 15
# [1] 11

# %%
dat = mf[c(vars_cat, vars_cts)]
dim(dat)
head(dat)
# Out:
# [1] 599  26
#   Sex  GIERACE SITE       TUDRAMT                         TURSMOKE
# 1 male 1:WHITE Birmingham 1: Less than one drink per week M:Not Applicable
# 2 male 1:WHITE Birmingham 0:None drinker                  1:PAST
# 3 male 1:WHITE Birmingham 0:None drinker                  1:PAST
# 4 male 1:WHITE Birmingham 4: 6-13 drinks per week         1:PAST
# 5 male 1:WHITE Birmingham 3: 3-5 drinks per week          1:PAST
# 6 male 1:WHITE Birmingham 0:None drinker                  1:PAST
#   M1ADEPR M1VITMND M1ANTIB M1PROBI OHSEAS   ⋯ Longitude Age BMI      PASCORE
# 1 0: No   0: No    0: No   0: No   3:SUMMER ⋯ -86.80249 83  28.89012  91.00000
# 2 0: No   1: Yes   1: Yes  0: No   2:SPRING ⋯ -86.80249 81  28.53980 199.17857
# 3 0: No   1: Yes   0: No   0: No   2:SPRING ⋯ -86.80249 83  25.01424 161.71429
# 4 0: No   1: Yes   0: No   0: No   2:SPRING ⋯ -86.80249 79  30.87637  88.21429
# 5 0: No   0: No    0: No   0: No   4:FALL   ⋯ -86.80249 81  33.58739 256.82143
# 6 0: No   0: No    1: Yes  0: No   2:SPRING ⋯ -86.80249 80  26.41523 179.57143
#   DTVITD Rstarch_total OHV1D3 OHV24D3 OHVD3 alpha_pd
# 1 250.90 3.066569      0.0393 1.77    25.8  27.77117
# 2  72.97 3.038136      0.0619 3.91    39.2  17.93266
# 3 312.15 2.840599      0.0521 1.49    23.1  21.45366
# 4 323.52 4.106798      0.0431 2.14    27.3  18.46968
# 5  31.95 0.971114      0.0502 3.62    33.0  20.04983
# 6 156.06 4.813568      0.0455 1.79    19.5  13.75183

# %%
summary(dat)
# Out:
#    Sex                    GIERACE             SITE
#  male:599   1:WHITE           :520   Birmingham : 75
#             2:AFRICAN AMERICAN: 24   Minneapolis: 91
#             3:ASIAN           : 34   Palo Alto  : 86
#             4:HISPANIC        : 12   Pittsburgh : 92
#             5:OTHER           :  9   Portland   :121
#                                      San Diego  :134
#
#                             TUDRAMT                TURSMOKE     M1ADEPR
#  .                              :  2   0:NO            :230   0: No :546
#  0:None drinker                 :230   1:PAST          :289   1: Yes: 53
#  1: Less than one drink per week: 78   2:CURRENT       :  9
#  2: 1-2drinks per week          : 66   M:Not Applicable: 71
#  3: 3-5 drinks per week         : 90
#  4: 6-13 drinks per week        :106
#  5: 14 or more drinks per week  : 27
#    M1VITMND     M1ANTIB      M1PROBI                       OHSEAS
#  0: No :154   0: No :558   0: No :573   1:WINTER              :  6
#  1: Yes:445   1: Yes: 41   1: Yes: 26   2:SPRING              :211
#                                         3:SUMMER              :220
#                                         4:FALL                :130
#                                         Missing:Not collected : 32
#
#
#               QLCOMP                      VDstatus     M1STATIN   Antihistamine
#  0:PR/VPOOR/FAIR : 66                         : 11   0: No :263   0:No :540
#  1:GOOD/EXCELLENT:533   deficiency            : 40   1: Yes:336   1:Yes: 59
#                         Missing:Not collected : 32
#                         sufficiency           :516
#
#
#
#   Laxative      Latitude       Longitude           Age             BMI
#  0:No :505   Min.   :32.72   Min.   :-122.7   Min.   :78.00   Min.   :17.60
#  1:Yes: 94   1st Qu.:33.52   1st Qu.:-122.1   1st Qu.:81.00   1st Qu.:24.51
#              Median :40.44   Median :-117.2   Median :83.00   Median :26.72
#              Mean   :39.13   Mean   :-105.9   Mean   :84.24   Mean   :27.01
#              3rd Qu.:44.98   3rd Qu.: -86.8   3rd Qu.:87.00   3rd Qu.:28.98
#              Max.   :45.52   Max.   : -80.0   Max.   :98.00   Max.   :42.93
#
#     PASCORE           DTVITD        Rstarch_total        OHV1D3
#  Min.   :  0.00   Min.   :  0.429   Min.   : 0.100   Min.   :0.01070
#  1st Qu.: 70.14   1st Qu.: 77.963   1st Qu.: 1.251   1st Qu.:0.04410
#  Median :116.75   Median :128.125   Median : 2.360   Median :0.05550
#  Mean   :122.48   Mean   :164.396   Mean   : 2.685   Mean   :0.05777
#  3rd Qu.:165.79   3rd Qu.:211.643   3rd Qu.: 3.613   3rd Qu.:0.06630
#  Max.   :359.14   Max.   :982.830   Max.   :12.386   Max.   :0.15600
#                   NA's   :15        NA's   :15       NA's   :32
#     OHV24D3           OHVD3           alpha_pd
#  Min.   : 0.300   Min.   :  7.80   Min.   : 3.90
#  1st Qu.: 2.175   1st Qu.: 27.40   1st Qu.:16.32
#  Median : 3.180   Median : 33.65   Median :20.25
#  Mean   : 3.431   Mean   : 35.23   Mean   :21.09
#  3rd Qu.: 4.235   3rd Qu.: 41.83   3rd Qu.:25.87
#  Max.   :14.070   Max.   :104.00   Max.   :44.03
#  NA's   :32       NA's   :43

# %%
dat = dat[complete.cases(dat), ]
print(dim(dat))
alpha = dat$alpha_pd
dat = dat[, -which(names(dat) %in% 'alpha_pd')]
dim(dat)
# Out:
# [1] 545  26
# [1] 545  25

# %%
mod0 <- rda(alpha ~ 1., dat)  # Model with intercept only
mod1 <- rda(alpha ~ ., dat)  # Model with all explanatory variables

# %%
step.res <- ordiR2step(mod0, mod1, perm.max = 1000)
# Out:
# Step: R2.adj= 0
# Call: alpha ~ 1
#
#                   R2.adjusted
# <All variables>  0.1358048025
# + OHV1D3         0.0528995868
# + M1ANTIB        0.0227745101
# + GIERACE        0.0202594070
# + TUDRAMT        0.0193169647
# + SITE           0.0192963887
# + M1ADEPR        0.0134676017
# + OHV24D3        0.0126697060
# + Rstarch_total  0.0113206998
# + Latitude       0.0083159884
# + BMI            0.0047408113
# + OHSEAS         0.0042540575
# + PASCORE        0.0040791226
# + Age            0.0014860303
# + M1STATIN       0.0010203332
# + Longitude      0.0007589433
# + Laxative       0.0006233309
# + QLCOMP         0.0001640037
# <none>           0.0000000000
# + Sex            0.0000000000
# + VDstatus      -0.0003741624
# + OHVD3         -0.0011360122
# + M1PROBI       -0.0015039770
# + DTVITD        -0.0016382488
# + Antihistamine -0.0016647839
# + M1VITMND      -0.0016727506
# + TURSMOKE      -0.0037498847
#
#          Df  AIC      F Pr(>F)
# + OHV1D3  1 1983 31.385  0.002 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.05289959
# Call: alpha ~ OHV1D3
#
#                 R2.adjusted
# <All variables>  0.13580480
# + GIERACE        0.07071292
# + M1ANTIB        0.07048867
# + SITE           0.06874575
# + Rstarch_total  0.06855980
# + TUDRAMT        0.06357999
# + M1ADEPR        0.06265321
# + Latitude       0.06169936
# + OHSEAS         0.05945298
# + OHVD3          0.05823858
# + Age            0.05708179
# + M1STATIN       0.05535314
# + Laxative       0.05417532
# + BMI            0.05351717
# + M1VITMND       0.05297292
# <none>           0.05289959
# + Sex            0.05289959
# + M1PROBI        0.05273353
# + Longitude      0.05272124
# + PASCORE        0.05268246
# + DTVITD         0.05161462
# + OHV24D3        0.05152643
# + Antihistamine  0.05150722
# + QLCOMP         0.05141660
# + VDstatus       0.05135090
# + TURSMOKE       0.04887921
#
#           Df    AIC      F Pr(>F)
# + GIERACE  4 1976.6 3.6022  0.012 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.07071292
# Call: alpha ~ OHV1D3 + GIERACE
#
#                 R2.adjusted
# <All variables>  0.13580480
# + M1ANTIB        0.08771212
# + SITE           0.08588106
# + M1ADEPR        0.08288175
# + Rstarch_total  0.08168241
# + OHSEAS         0.07906050
# + OHVD3          0.07753694
# + TUDRAMT        0.07741345
# + Latitude       0.07605415
# + Longitude      0.07452441
# + BMI            0.07418807
# + Age            0.07393053
# + M1STATIN       0.07322254
# + Laxative       0.07235554
# + PASCORE        0.07118035
# + M1PROBI        0.07074972
# <none>           0.07071292
# + Sex            0.07071292
# + M1VITMND       0.07011667
# + DTVITD         0.07011163
# + OHV24D3        0.06956636
# + QLCOMP         0.06938902
# + Antihistamine  0.06932822
# + VDstatus       0.06902032
# + TURSMOKE       0.06715006
#
#           Df    AIC      F Pr(>F)
# + M1ANTIB  1 1967.6 11.043  0.004 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.08771212
# Call: alpha ~ OHV1D3 + GIERACE + M1ANTIB
#
#                 R2.adjusted
# <All variables>  0.13580480
# + SITE           0.10115806
# + M1ADEPR        0.10033582
# + Rstarch_total  0.09760421
# + OHSEAS         0.09706564
# + TUDRAMT        0.09617366
# + OHVD3          0.09461264
# + Longitude      0.09187733
# + M1STATIN       0.09045767
# + Age            0.09026244
# + Latitude       0.09009316
# + BMI            0.08998864
# + Laxative       0.08934039
# + PASCORE        0.08810250
# <none>           0.08771212
# + Sex            0.08771212
# + DTVITD         0.08706108
# + OHV24D3        0.08692511
# + Antihistamine  0.08686129
# + M1PROBI        0.08666891
# + M1VITMND       0.08665060
# + QLCOMP         0.08617506
# + VDstatus       0.08614886
# + TURSMOKE       0.08366157
#
#        Df    AIC      F Pr(>F)
# + SITE  5 1964.4 2.6096   0.03 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.1011581
# Call: alpha ~ OHV1D3 + GIERACE + M1ANTIB + SITE
#
#                 R2.adjusted
# <All variables>  0.13580480
# + M1ADEPR        0.11372319
# + OHSEAS         0.10952689
# + Rstarch_total  0.10830535
# + OHVD3          0.10787597
# + TUDRAMT        0.10582333
# + Laxative       0.10337307
# + M1STATIN       0.10336346
# + PASCORE        0.10333447
# + Age            0.10332187
# + BMI            0.10253605
# <none>           0.10115806
# + Sex            0.10115806
# + Latitude       0.10115806
# + Longitude      0.10115806
# + DTVITD         0.10112105
# + OHV24D3        0.10073297
# + M1PROBI        0.10025878
# + M1VITMND       0.10024003
# + Antihistamine  0.09982521
# + VDstatus       0.09959457
# + QLCOMP         0.09950585
# + TURSMOKE       0.09684102
#
#           Df    AIC      F Pr(>F)
# + M1ADEPR  1 1957.7 8.5566  0.004 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Step: R2.adj= 0.1137232
# Call: alpha ~ OHV1D3 + GIERACE + M1ANTIB + SITE + M1ADEPR
#
#                 R2.adjusted
# <All variables>   0.1358048
# + OHSEAS          0.1206086
# + Rstarch_total   0.1192968
# + OHVD3           0.1185071
# + TUDRAMT         0.1170438
# + Age             0.1158780
# + BMI             0.1157433
# + Laxative        0.1157198
# + M1STATIN        0.1156261
# + PASCORE         0.1155825
# <none>            0.1137232
# + Sex             0.1137232
# + Latitude        0.1137232
# + Longitude       0.1137232
# + DTVITD          0.1134653
# + M1PROBI         0.1129913
# + Antihistamine   0.1128520
# + OHV24D3         0.1127700
# + M1VITMND        0.1127613
# + VDstatus        0.1121268
# + QLCOMP          0.1120738
# + TURSMOKE        0.1097131
#
#          Df    AIC      F Pr(>F)
# + OHSEAS  3 1956.4 2.3885  0.076 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
table = step.res$anova
table
# Out:
#                 R2.adj     Df AIC      F         Pr(>F)
# + OHV1D3        0.05289959  1 1983.022 31.384714 0.002
# + GIERACE       0.07071292  4 1976.645  3.602167 0.012
# + M1ANTIB       0.08771212  1 1967.571 11.043508 0.004
# + SITE          0.10115806  5 1964.390  2.609608 0.030
# + M1ADEPR       0.11372319  1 1957.694  8.556572 0.004
# <All variables> 0.13580480 NA       NA        NA    NA

# %%
table$ES.RDA = c(table$R2.adj[1], table$R2.adj[2]-table$R2.adj[1], 
                       table$R2.adj[3]-table$R2.adj[2], table$R2.adj[4]-table$R2.adj[3],
                       table$R2.adj[5]-table$R2.adj[4], table$R2.adj[6]-table$R2.adj[5])
table = table[-6, ]

# %%
step.res$call
# Out:
# rda(formula = alpha ~ OHV1D3 + GIERACE + M1ANTIB + SITE + M1ADEPR,
#     data = dat)

# %%
table
# Out:
#           R2.adj     Df AIC      F         Pr(>F) ES.RDA
# + OHV1D3  0.05289959 1  1983.022 31.384714 0.002  0.05289959
# + GIERACE 0.07071292 4  1976.645  3.602167 0.012  0.01781333
# + M1ANTIB 0.08771212 1  1967.571 11.043508 0.004  0.01699920
# + SITE    0.10115806 5  1964.390  2.609608 0.030  0.01344594
# + M1ADEPR 0.11372319 1  1957.694  8.556572 0.004  0.01256513

# %%
rownames(table) = c('1,25-(OH)2D', 'Race', 'Oral Antibiotic Use', 'Site', 'Antidepressant Use')

# %%
library(ggplot2)
pdf('../figures/RDA_alpha.pdf')
covariates = rownames(table)
ggplot(table, aes(x=reorder(covariates, ES.RDA), y=ES.RDA, fill=covariates)) +
  labs(x = 'Non-redundant Covariants', y = 'Effect Size (PD Alpha Diversity)') +
  geom_bar(stat='identity') +
 theme(axis.text=element_text(size=14, face='bold'), 
       axis.title=element_text(size=17,face="bold"), 
       legend.position="none") + 
  coord_flip()
dev.off()
# Out:
# pdf
#   2

# %%
attach(mf)

# %%
pdf('../figures/boxplot_AlphaRDAcovariates.pdf')
par(mfrow=c(2,2))
boxplot(alpha_pd ~ GIERACE, main='Race', ylab='PD Alpha Diversity', 
       names=c('White', 'Black', 'Asian', 'Hispanic', 'Other'), las=2)
boxplot(alpha_pd ~ SITE, main='Site', ylab='', 
       names=c('BI', 'MN', 'PA', 'PI', 'PO', 'SD'))
boxplot(alpha_pd ~ M1ANTIB, main='Antibiotic Use', ylab='PD Alpha Diversity')
boxplot(alpha_pd ~ M1ADEPR, main='Antidepressent Use')
dev.off()
# Out:
# pdf
#   2
