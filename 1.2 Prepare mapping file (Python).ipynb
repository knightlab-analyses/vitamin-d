# %% [markdown]
# This notebook is to add additional covariates (health, stool info, medication, dietary history) to the mapping file.

# %%
import pandas as pd
import numpy as np

# %%
mf = pd.read_csv('../data/mapping_MrOS.txt', sep='\t', dtype=str, index_col='#SampleID')

# %%
print(mf.shape)
mf.head()
# Out:
# (599, 64)
#           BarcodeSequence  LinkerPrimerSequence  \
# #SampleID
# BI0023       TCTGGTGACATT  GGACTACHVGGGTWTCTAAT
# BI0056       CAAGCATGCCTA  GGACTACHVGGGTWTCTAAT
# BI0131       CTATTTGCGACA  GGACTACHVGGGTWTCTAAT
# BI0153       ATCGGCGTTACA  GGACTACHVGGGTWTCTAAT
# BI0215       CCTCTCGTGATC  GGACTACHVGGGTWTCTAAT
#
#                                Experiment_Design_Description  \
# #SampleID
# BI0023     16S stool samples sequenced for MrOS Vitamin D...
# BI0056     16S stool samples sequenced for MrOS Vitamin D...
# BI0131     16S stool samples sequenced for MrOS Vitamin D...
# BI0153     16S stool samples sequenced for MrOS Vitamin D...
# BI0215     16S stool samples sequenced for MrOS Vitamin D...
#
#           Library_Construction_Protocol Linker  Platform Center_Name  \
# #SampleID
# BI0023                      16S rRNA v4     GT  Illumina          BI
# BI0056                      16S rRNA v4     GT  Illumina          BI
# BI0131                      16S rRNA v4     GT  Illumina          BI
# BI0153                      16S rRNA v4     GT  Illumina          BI
# BI0215                      16S rRNA v4     GT  Illumina          BI
#
#           Center_Project Instrument_Model          Title  ... OHVD3 OHVD2  \
# #SampleID                                                 ...
# BI0023              MrOS   Illumina MiSeq  MrOS_VitaminD  ...  25.8   0.0
# BI0056              MrOS   Illumina MiSeq  MrOS_VitaminD  ...  39.2   0.0
# BI0131              MrOS   Illumina MiSeq  MrOS_VitaminD  ...  23.1   0.0
# BI0153              MrOS   Illumina MiSeq  MrOS_VitaminD  ...  27.3   0.0
# BI0215              MrOS   Illumina MiSeq  MrOS_VitaminD  ...    33   0.0
#
#           OHV1D2 OHV1D2CT OHVD2CT OHVDTOT OHV1DTOT    OHSEAS     VDstatus  \
# #SampleID
# BI0023       0.0   1: Yes  1: Yes    25.8     39.3  3:SUMMER  sufficiency
# BI0056       0.0   1: Yes  1: Yes    39.2     61.9  2:SPRING  sufficiency
# BI0131       0.0   1: Yes  1: Yes    23.1     52.1  2:SPRING  sufficiency
# BI0153       0.0   1: Yes  1: Yes    27.3     43.1  2:SPRING  sufficiency
# BI0215       0.0   1: Yes  1: Yes    33.0     50.2    4:FALL  sufficiency
#
#                 Description
# #SampleID
# BI0023     Orwoll.BI0023.BI
# BI0056     Orwoll.BI0056.BI
# BI0131     Orwoll.BI0131.BI
# BI0153     Orwoll.BI0153.BI
# BI0215     Orwoll.BI0215.BI
#
# [5 rows x 64 columns]

# %% [markdown]
# ## convert covariates to proper continuous or categorical format

# %%
vars_cat = np.array(['BarcodeSequence', 'LinkerPrimerSequence', 'Experiment_Design_Description',
             'Library_Construction_Protocol', 'Linker', 'Platform', 'Center_Name', 'Center_Project', 'Instrument_Model',
             'Title', 'Anonymized_Name', 'Scientific_Name', 'Taxon_ID', 'Sample_Type', 'Geo_Loc_Name', 'Elevation', 'Env_Biome',
             'Env_Feature', 'Env_Material', 'Env_Package', 'Collection_Timestamp', 'DNA_Extracted', 'Physical_Specimen_Location',
             'Physical_Specimen_Remaining', 'Age_Units', 'Host_Subject_ID', 'Host_Taxid','Host_Scientific_Name', 'Host_Common_Name',
             'Life_Stage', 'Sex', 'Height_Units', 'Weight_Units', 'Body_Habitat', 'Body_Site', 'Body_Product', 'GIERACE', 'SITE',
             'TUDRAMT', 'TURSMOKE', 'M1ADEPR', 'M1VITMND', 'M1ANTIB', 'M1PROBI', 'OHSEAS', 'VDstatus', 'Description',
             'OHV1D2CT', 'OHVD2CT'])
vars_cts = np.array(['Latitude', 'Longitude', 'Age', 'Height', 'Weight', 'BMI', 'PASCORE', 'DTVITD', 
             'OHV1D3', 'OHV24D3', 'OHVD3', 'OHVD2', 'OHV1D2',  'OHVDTOT', 'OHV1DTOT'])

# %%
# convert vars_cts to numeric and vars_cat to factors
df = mf.copy()
df[vars_cts] = df[vars_cts].apply(pd.to_numeric, errors='coerce')
df[vars_cat] = df[vars_cat].apply(lambda x: x.astype('category'))

# %%
# convert all pg/ml to ng/ml note: 1 ng/ml = 1000 pg/ml
df.OHV1D3 = df.OHV1D3/1000
df.OHV1D2 = df.OHV1D2/1000
df.OHV1DTOT = df.OHV1DTOT/1000

# %% [markdown]
# ## add two ratio variables of Vitamin D

# %%
df['ratio_activation'] = df.OHV1D3/df.OHVD3
df['ratio_catabolism'] = df.OHV24D3/df.OHVD3 
vars_cts = np.append(vars_cts, ['ratio_activation', 'ratio_catabolism'])

# %%
df[vars_cts].describe()
# Out:
#          Latitude   Longitude         Age      Height      Weight         BMI  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    39.131492 -105.850862   84.237062  172.143573   80.173957   27.009647
# std      5.226215   17.221362    4.061471    6.803620   12.994918    3.788662
# min     32.715738 -122.676500   78.000000  153.850000   51.400000   17.599566
# 25%     33.520661 -122.143000   81.000000  167.325000   71.000000   24.506948
# 50%     40.440625 -117.161100   83.000000  172.100000   79.000000   26.724552
# 75%     44.977753  -86.802490   87.000000  176.725000   87.500000   28.975480
# max     45.523062  -79.995890   98.000000  194.650000  127.600000   42.931509
#
#           PASCORE      DTVITD      OHV1D3     OHV24D3       OHVD3       OHVD2  \
# count  599.000000  584.000000  567.000000  567.000000  556.000000  567.000000
# mean   122.482829  164.395957    0.057775    3.430864   35.229137    0.769136
# std     66.667650  127.458600    0.019773    1.834771   12.450758    4.266210
# min      0.000000    0.429000    0.010700    0.300000    7.800000    0.000000
# 25%     70.142857   77.962500    0.044100    2.175000   27.400000    0.000000
# 50%    116.750000  128.125000    0.055500    3.180000   33.650000    0.000000
# 75%    165.785714  211.642500    0.066300    4.235000   41.825000    0.000000
# max    359.142857  982.830000    0.156000   14.070000  104.000000   59.000000
#
#            OHV1D2     OHVDTOT    OHV1DTOT  ratio_activation  ratio_catabolism
# count  567.000000  556.000000  567.000000        556.000000        556.000000
# mean     0.000177   36.013489    0.057951          0.001772          0.094776
# std      0.002232   12.410942    0.019656          0.000735          0.029770
# min      0.000000    7.800000    0.010700          0.000398          0.018788
# 25%      0.000000   28.100000    0.044250          0.001316          0.074216
# 50%      0.000000   34.150000    0.055500          0.001660          0.092821
# 75%      0.000000   42.300000    0.066450          0.002081          0.112849
# max      0.037800  104.000000    0.156000          0.006727          0.197786

# %%
df[vars_cat].describe()
# Out:
#        BarcodeSequence  LinkerPrimerSequence  \
# count              599                   599
# unique             599                     1
# top       TTGTCTGGAAGC  GGACTACHVGGGTWTCTAAT
# freq                 1                   599
#
#                             Experiment_Design_Description  \
# count                                                 599
# unique                                                  1
# top     16S stool samples sequenced for MrOS Vitamin D...
# freq                                                  599
#
#        Library_Construction_Protocol Linker  Platform Center_Name  \
# count                            599    599       599         599
# unique                             1      1         1           6
# top                      16S rRNA v4     GT  Illumina          SD
# freq                             599    599       599         134
#
#        Center_Project Instrument_Model          Title  ... TURSMOKE M1ADEPR  \
# count             599              599            599  ...      599     599
# unique              1                1              1  ...        4       2
# top              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   1:PAST   0: No
# freq              599              599            599  ...      289     546
#
#        M1VITMND M1ANTIB M1PROBI    OHSEAS     VDstatus       Description  \
# count       599     599     599       599          588               599
# unique        2       2       2         5            3               599
# top      1: Yes   0: No   0: No  3:SUMMER  sufficiency  Orwoll.SD9009.SD
# freq        445     558     573       220          516                 1
#
#        OHV1D2CT OHVD2CT
# count       599     599
# unique        3       3
# top      1: Yes  1: Yes
# freq        563     448
#
# [4 rows x 49 columns]

# %%
# count missing values
df[vars_cts].isnull().sum()
# Out:
# Latitude             0
# Longitude            0
# Age                  0
# Height               0
# Weight               0
# BMI                  0
# PASCORE              0
# DTVITD              15
# OHV1D3              32
# OHV24D3             32
# OHVD3               43
# OHVD2               32
# OHV1D2              32
# OHVDTOT             43
# OHV1DTOT            32
# ratio_activation    43
# ratio_catabolism    43
# dtype: int64

# %%
# check
df.shape
# Out:
# (599, 66)

# %% [markdown]
# ## add health variables

# %%
health = pd.read_csv('../data/MrOS_healthvari.csv', sep=',', dtype=str)
health = health.rename(columns={'ID': '#SampleID'}).set_index('#SampleID')
health['QLCOMP'] = health['QLCOMP'].astype('category')

# %%
df = pd.merge(df, health, left_index=True, right_index=True)

# %%
print(df.shape)
df.head()
# Out:
# (599, 67)
#           BarcodeSequence  LinkerPrimerSequence  \
# #SampleID
# BI0023       TCTGGTGACATT  GGACTACHVGGGTWTCTAAT
# BI0056       CAAGCATGCCTA  GGACTACHVGGGTWTCTAAT
# BI0131       CTATTTGCGACA  GGACTACHVGGGTWTCTAAT
# BI0153       ATCGGCGTTACA  GGACTACHVGGGTWTCTAAT
# BI0215       CCTCTCGTGATC  GGACTACHVGGGTWTCTAAT
#
#                                Experiment_Design_Description  \
# #SampleID
# BI0023     16S stool samples sequenced for MrOS Vitamin D...
# BI0056     16S stool samples sequenced for MrOS Vitamin D...
# BI0131     16S stool samples sequenced for MrOS Vitamin D...
# BI0153     16S stool samples sequenced for MrOS Vitamin D...
# BI0215     16S stool samples sequenced for MrOS Vitamin D...
#
#           Library_Construction_Protocol Linker  Platform Center_Name  \
# #SampleID
# BI0023                      16S rRNA v4     GT  Illumina          BI
# BI0056                      16S rRNA v4     GT  Illumina          BI
# BI0131                      16S rRNA v4     GT  Illumina          BI
# BI0153                      16S rRNA v4     GT  Illumina          BI
# BI0215                      16S rRNA v4     GT  Illumina          BI
#
#           Center_Project Instrument_Model          Title  ... OHV1D2CT  \
# #SampleID                                                 ...
# BI0023              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   1: Yes
# BI0056              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   1: Yes
# BI0131              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   1: Yes
# BI0153              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   1: Yes
# BI0215              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   1: Yes
#
#           OHVD2CT OHVDTOT OHV1DTOT    OHSEAS     VDstatus       Description  \
# #SampleID
# BI0023     1: Yes    25.8   0.0393  3:SUMMER  sufficiency  Orwoll.BI0023.BI
# BI0056     1: Yes    39.2   0.0619  2:SPRING  sufficiency  Orwoll.BI0056.BI
# BI0131     1: Yes    23.1   0.0521  2:SPRING  sufficiency  Orwoll.BI0131.BI
# BI0153     1: Yes    27.3   0.0431  2:SPRING  sufficiency  Orwoll.BI0153.BI
# BI0215     1: Yes    33.0   0.0502    4:FALL  sufficiency  Orwoll.BI0215.BI
#
#           ratio_activation ratio_catabolism            QLCOMP
# #SampleID
# BI0023            0.001523         0.068605  1:GOOD/EXCELLENT
# BI0056            0.001579         0.099745  1:GOOD/EXCELLENT
# BI0131            0.002255         0.064502  1:GOOD/EXCELLENT
# BI0153            0.001579         0.078388  1:GOOD/EXCELLENT
# BI0215            0.001521         0.109697  1:GOOD/EXCELLENT
#
# [5 rows x 67 columns]

# %% [markdown]
# ## add stool sample variables

# %%
stool = pd.read_csv('../data/Stool600comments_JS.txt', sep='\t', dtype=str)
stool = stool.rename(columns={'ID': '#SampleID'}).set_index('#SampleID')

# %%
id_stool = list(stool.index)
id_mapping = list(df.index)

for i in id_mapping:
    if i not in id_stool:
        print(i)
        
for i in id_stool:
    if i not in id_mapping:
        print(i)
# Out:
# PO7020
# PO7029
# PO7020
# PO7029
# PO7100

# %%
stool['Timestool '] = stool['Timestool '].astype('category') # notice a space in name
stool['Timestoolc'] = stool['Timestoolc'].astype('category')
stool['StoolCollected'] = stool['StoolCollected'].astype('category')
stool['StoolShipped'] = stool['StoolShipped'].astype('category')
stool['Days( between collection and shipment)'] = stool['Days( between collection and shipment)'].astype('category')
stool['StoolQualityC'] = stool['StoolQualityC'].astype('category')

# %% [markdown]
# ## add medication variables

# %%
med = pd.read_csv('../data/Microbiom_medsupdate.csv', sep=',', dtype=str)

# %%
med.head()
# Out:
#        ID M1STATIN Antihistamine Laxative
# 0  BI0023    0: No          0:No     0:No
# 1  BI0056    0: No          0:No     0:No
# 2  BI0131   1: Yes          0:No     0:No
# 3  BI0153   1: Yes          0:No     0:No
# 4  BI0215    0: No          0:No     0:No

# %%
med = med.rename(columns={'ID': '#SampleID'}).set_index('#SampleID')
med = med.apply(lambda x: x.astype('category'))

# %%
med.head()
# Out:
#           M1STATIN Antihistamine Laxative
# #SampleID
# BI0023       0: No          0:No     0:No
# BI0056       0: No          0:No     0:No
# BI0131      1: Yes          0:No     0:No
# BI0153      1: Yes          0:No     0:No
# BI0215       0: No          0:No     0:No

# %%
df = pd.merge(df, med, left_index=True, right_index=True)

# %%
df.shape
# Out:
# (599, 70)

# %%
df.head()
# Out:
#           BarcodeSequence  LinkerPrimerSequence  \
# #SampleID
# BI0023       TCTGGTGACATT  GGACTACHVGGGTWTCTAAT
# BI0056       CAAGCATGCCTA  GGACTACHVGGGTWTCTAAT
# BI0131       CTATTTGCGACA  GGACTACHVGGGTWTCTAAT
# BI0153       ATCGGCGTTACA  GGACTACHVGGGTWTCTAAT
# BI0215       CCTCTCGTGATC  GGACTACHVGGGTWTCTAAT
#
#                                Experiment_Design_Description  \
# #SampleID
# BI0023     16S stool samples sequenced for MrOS Vitamin D...
# BI0056     16S stool samples sequenced for MrOS Vitamin D...
# BI0131     16S stool samples sequenced for MrOS Vitamin D...
# BI0153     16S stool samples sequenced for MrOS Vitamin D...
# BI0215     16S stool samples sequenced for MrOS Vitamin D...
#
#           Library_Construction_Protocol Linker  Platform Center_Name  \
# #SampleID
# BI0023                      16S rRNA v4     GT  Illumina          BI
# BI0056                      16S rRNA v4     GT  Illumina          BI
# BI0131                      16S rRNA v4     GT  Illumina          BI
# BI0153                      16S rRNA v4     GT  Illumina          BI
# BI0215                      16S rRNA v4     GT  Illumina          BI
#
#           Center_Project Instrument_Model          Title  ... OHV1DTOT  \
# #SampleID                                                 ...
# BI0023              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   0.0393
# BI0056              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   0.0619
# BI0131              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   0.0521
# BI0153              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   0.0431
# BI0215              MrOS   Illumina MiSeq  MrOS_VitaminD  ...   0.0502
#
#              OHSEAS     VDstatus       Description ratio_activation  \
# #SampleID
# BI0023     3:SUMMER  sufficiency  Orwoll.BI0023.BI         0.001523
# BI0056     2:SPRING  sufficiency  Orwoll.BI0056.BI         0.001579
# BI0131     2:SPRING  sufficiency  Orwoll.BI0131.BI         0.002255
# BI0153     2:SPRING  sufficiency  Orwoll.BI0153.BI         0.001579
# BI0215       4:FALL  sufficiency  Orwoll.BI0215.BI         0.001521
#
#           ratio_catabolism            QLCOMP M1STATIN Antihistamine Laxative
# #SampleID
# BI0023            0.068605  1:GOOD/EXCELLENT    0: No          0:No     0:No
# BI0056            0.099745  1:GOOD/EXCELLENT    0: No          0:No     0:No
# BI0131            0.064502  1:GOOD/EXCELLENT   1: Yes          0:No     0:No
# BI0153            0.078388  1:GOOD/EXCELLENT   1: Yes          0:No     0:No
# BI0215            0.109697  1:GOOD/EXCELLENT    0: No          0:No     0:No
#
# [5 rows x 70 columns]

# %% [markdown]
# ## add starch variables

# %%
st = pd.read_csv('../data/Microbiome_DietaryStarchesnew.csv', sep=',')

# %%
st.shape
# Out:
# (600, 4)

# %%
st = st.rename(columns={'ID': '#SampleID', 'Rstarches_c (0: <5 and 1>=5)': 'Rstarches_c'}).set_index('#SampleID')

# %%
st.head()
# Out:
#            MIDATA  Rstarch_total  Rstarches_c
# #SampleID
# BI0023     1: Yes       3.066569          0.0
# BI0056     1: Yes       3.038136          0.0
# BI0131     1: Yes       2.840599          0.0
# BI0153     1: Yes       4.106798          0.0
# BI0215     1: Yes       0.971114          0.0

# %%
df = pd.merge(df, st, left_index=True, right_index=True)

# %%
df.shape
# Out:
# (599, 73)

# %% [markdown]
# ### add PPI medication information

# %%
ppi = pd.read_csv('../data/PPI_info_mros.txt', sep='\t')

# %%
ppi.shape
# Out:
# (599, 3)

# %%
ppi = ppi.rename(columns={'ID': '#SampleID'}).set_index('#SampleID')

# %%
ppi.head()
# Out:
#            MIDATA M1PPUMP
# #SampleID
# BI0023     1: Yes   0: No
# BI0056     1: Yes  1: Yes
# BI0131     1: Yes   0: No
# BI0153     1: Yes   0: No
# BI0215     1: Yes   0: No

# %%
ppi = ppi.drop(columns=['MIDATA'])
df = pd.merge(df, ppi, left_index=True, right_index=True)

# %%
df.shape
# Out:
# (599, 74)

# %% [markdown]
# ## output new mapping file

# %%
df.to_csv('../data/mapping_MrOS_add.txt', sep='\t', index_label='#SampleID')

# %%
df.head()
# Out:
#           BarcodeSequence  LinkerPrimerSequence  \
# #SampleID
# BI0023       TCTGGTGACATT  GGACTACHVGGGTWTCTAAT
# BI0056       CAAGCATGCCTA  GGACTACHVGGGTWTCTAAT
# BI0131       CTATTTGCGACA  GGACTACHVGGGTWTCTAAT
# BI0153       ATCGGCGTTACA  GGACTACHVGGGTWTCTAAT
# BI0215       CCTCTCGTGATC  GGACTACHVGGGTWTCTAAT
#
#                                Experiment_Design_Description  \
# #SampleID
# BI0023     16S stool samples sequenced for MrOS Vitamin D...
# BI0056     16S stool samples sequenced for MrOS Vitamin D...
# BI0131     16S stool samples sequenced for MrOS Vitamin D...
# BI0153     16S stool samples sequenced for MrOS Vitamin D...
# BI0215     16S stool samples sequenced for MrOS Vitamin D...
#
#           Library_Construction_Protocol Linker  Platform Center_Name  \
# #SampleID
# BI0023                      16S rRNA v4     GT  Illumina          BI
# BI0056                      16S rRNA v4     GT  Illumina          BI
# BI0131                      16S rRNA v4     GT  Illumina          BI
# BI0153                      16S rRNA v4     GT  Illumina          BI
# BI0215                      16S rRNA v4     GT  Illumina          BI
#
#           Center_Project Instrument_Model          Title  ...  \
# #SampleID                                                 ...
# BI0023              MrOS   Illumina MiSeq  MrOS_VitaminD  ...
# BI0056              MrOS   Illumina MiSeq  MrOS_VitaminD  ...
# BI0131              MrOS   Illumina MiSeq  MrOS_VitaminD  ...
# BI0153              MrOS   Illumina MiSeq  MrOS_VitaminD  ...
# BI0215              MrOS   Illumina MiSeq  MrOS_VitaminD  ...
#
#           ratio_activation ratio_catabolism            QLCOMP M1STATIN  \
# #SampleID
# BI0023            0.001523         0.068605  1:GOOD/EXCELLENT    0: No
# BI0056            0.001579         0.099745  1:GOOD/EXCELLENT    0: No
# BI0131            0.002255         0.064502  1:GOOD/EXCELLENT   1: Yes
# BI0153            0.001579         0.078388  1:GOOD/EXCELLENT   1: Yes
# BI0215            0.001521         0.109697  1:GOOD/EXCELLENT    0: No
#
#           Antihistamine Laxative  MIDATA Rstarch_total Rstarches_c M1PPUMP
# #SampleID
# BI0023             0:No     0:No  1: Yes      3.066569         0.0   0: No
# BI0056             0:No     0:No  1: Yes      3.038136         0.0  1: Yes
# BI0131             0:No     0:No  1: Yes      2.840599         0.0   0: No
# BI0153             0:No     0:No  1: Yes      4.106798         0.0   0: No
# BI0215             0:No     0:No  1: Yes      0.971114         0.0   0: No
#
# [5 rows x 74 columns]
